# %% [markdown]
# **FIFA Player Stats (mini Kaggle project)**
#
# - Use a dataset like [FIFA players stats](https://www.kaggle.com/datasets/stefanoleone992/fifa-20-complete-player-dataset).
# - Load into Pandas, clean columns (convert wages like "€200K" into numbers using NumPy).
# - Analyze top 10 players by Overall, find distribution of player positions.
# - Plot: scatter plot of `Overall vs. Potential`, pie chart of positions.

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("./../data/players_20.csv")

# %%
def normalize_wages(x):
    if type(x) !=str:
        return x
    if "k" in x.lower():
        return int(x.lower().replace("k","").replace("€",""))*1000
    return int(x.lower().replace("€","")) 
 
df['wage_eur'] = df['wage_eur'].apply(normalize_wages)

# %%
df.sort_values(by="overall", ascending=False).head(10)
# Out:
#    sofifa_id                                         player_url         short_name                            long_name  age         dob  height_cm  weight_kg  nationality                 club  overall  potential  value_eur  wage_eur player_positions preferred_foot  international_reputation  weak_foot  skill_moves      work_rate            body_type real_face  release_clause_eur                                        player_tags team_position  team_jersey_number loaned_from      joined  contract_valid_until nation_position  nation_jersey_number  pace  shooting  passing  dribbling  defending  physic  gk_diving  gk_handling  gk_kicking  gk_reflexes  gk_speed  gk_positioning                                      player_traits  attacking_crossing  attacking_finishing  attacking_heading_accuracy  attacking_short_passing  attacking_volleys  skill_dribbling  skill_curve  skill_fk_accuracy  skill_long_passing  skill_ball_control  movement_acceleration  movement_sprint_speed  movement_agility 
# ...

# %%
plt.figure(figsize=(5,3),dpi=150)
sample = df.sample(100,random_state=5)
plt.scatter(sample.overall,sample.potential,c=sample.potential/sample.overall)
plt.xlabel("Overall")
plt.ylabel("Potential")
plt.show()

# %%
plt.figure(figsize=(5,3),dpi=150)
sample = df.sample(10,random_state=5)
sample = sample.player_positions.value_counts().reset_index(name="players")
plt.pie(sample.players,labels=sample.player_positions)
plt.show()
