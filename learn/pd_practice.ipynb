# %%
import pandas as pd

# %%
bios_new = pd.read_csv("./data/bios_new.csv")
bios = pd.read_csv("./data/bios.csv")
noc_regions = pd.read_csv("./data/noc_regions.csv")
results = pd.read_csv("./data/results.csv")

# %%
bios_new.head()
# Out:
#    athlete_id                   name   born_date    born_city  \
# 0           1  Jean-François Blanchy  1886-12-12     Bordeaux
# 1           2         Arnaud Boetsch  1969-04-01       Meulan
# 2           3           Jean Borotra  1898-08-13     Biarritz
# 3           4        Jacques Brugnon  1895-05-11  Paris VIIIe
# 4           5           Albert Canet  1878-04-17   Wandsworth
#
#             born_region born_country     NOC  height_cm  weight_kg  \
# 0               Gironde          FRA  France        NaN        NaN
# 1              Yvelines          FRA  France      183.0       76.0
# 2  Pyrénées-Atlantiques          FRA  France      183.0       76.0
# 3                 Paris          FRA  France      168.0       64.0
# 4               England          GBR  France        NaN        NaN
#
#     died_date     first_name born_datetime  born_year
# 0  1960-10-02  Jean-François    1886-12-12     1886.0
# 1         NaN         Arnaud    1969-04-01     1969.0
# ...

# %%
bios.head()
# Out:
#    athlete_id                   name   born_date    born_city  \
# 0           1  Jean-François Blanchy  1886-12-12     Bordeaux
# 1           2         Arnaud Boetsch  1969-04-01       Meulan
# 2           3           Jean Borotra  1898-08-13     Biarritz
# 3           4        Jacques Brugnon  1895-05-11  Paris VIIIe
# 4           5           Albert Canet  1878-04-17   Wandsworth
#
#             born_region born_country     NOC  height_cm  weight_kg   died_date
# 0               Gironde          FRA  France        NaN        NaN  1960-10-02
# 1              Yvelines          FRA  France      183.0       76.0         NaN
# 2  Pyrénées-Atlantiques          FRA  France      183.0       76.0  1994-07-17
# 3                 Paris          FRA  France      168.0       64.0  1978-03-20
# 4               England          GBR  France        NaN        NaN  1930-07-25

# %%
noc_regions.head()
# Out:
#    NOC       region                 notes
# 0  AFG  Afghanistan                   NaN
# 1  AHO      Curacao  Netherlands Antilles
# 2  ALB      Albania                   NaN
# 3  ALG      Algeria                   NaN
# 4  AND      Andorra                   NaN

# %%
results.head()
# Out:
#      year    type discipline                     event                     as  \
# 0  1912.0  Summer     Tennis    Singles, Men (Olympic)  Jean-François Blanchy
# 1  1912.0  Summer     Tennis    Doubles, Men (Olympic)  Jean-François Blanchy
# 2  1920.0  Summer     Tennis    Singles, Men (Olympic)  Jean-François Blanchy
# 3  1920.0  Summer     Tennis  Doubles, Mixed (Olympic)  Jean-François Blanchy
# 4  1920.0  Summer     Tennis    Doubles, Men (Olympic)  Jean-François Blanchy
#
#    athlete_id  noc             team  place   tied medal
# 0           1  FRA              NaN   17.0   True   NaN
# 1           1  FRA   Jean Montariol    NaN  False   NaN
# 2           1  FRA              NaN   32.0   True   NaN
# 3           1  FRA  Jeanne Vaussard    8.0   True   NaN
# 4           1  FRA  Jacques Brugnon    4.0  False   NaN

# %%
bios[bios['born_city'].str.lower()=="paris"]
# Out:
#         athlete_id                name   born_date born_city born_region  \
# 453            454    Catherine Pellen  1956-12-04     Paris       Paris
# 471            472     Claude Franclet  1964-06-23     Paris       Paris
# 488            489       Eugène Mougin  1852-11-17     Paris       Paris
# 2979          2991  Jean-Marc Augustin  1965-04-07     Paris       Paris
# 2987          2999      Saïd Ben Najem  1968-05-21     Paris       Paris
# ...            ...                 ...         ...       ...         ...
# 139403      142875       Arnaud Nordin  1998-06-17     Paris       Paris
# 139420      142893      Antoine Rozner  1993-02-12     Paris       Paris
# 139423      142896            Dika Mem  1997-08-31     Paris       Paris
# 139450      142923      Hadrien Salvan  1997-07-10     Paris       Paris
# 141112      144651       Remi Anri Doi  1989-09-28     Paris       Paris
#
#        born_country     NOC  height_cm  weight_kg   died_date
# ...

# %%
bios[bios['height_cm'] > 180]
# Out:
#         athlete_id               name   born_date        born_city  \
# 1                2     Arnaud Boetsch  1969-04-01           Meulan
# 2                3       Jean Borotra  1898-08-13         Biarritz
# 5                6  Nicolas Chatelain  1970-01-13           Amiens
# 16              17         Guy Forget  1965-01-04       Casablanca
# 25              26      Henri Leconte  1963-07-04          Lillers
# ...            ...                ...         ...              ...
# 145465      149192  Stanislav Galiyev  1992-01-17  Moskva (Moscow)
# 145466      149193     Mikkel Aagaard  1995-10-18    Frederikshavn
# 145468      149195  Justin Abdelkader  1987-02-25         Muskegon
# 145473      149200     Toms Andersons  1993-11-25             Rīga
# 145494      149221      George Wright  1890-07-21          Toronto
#
#                  born_region born_country            NOC  height_cm  \
# 1                   Yvelines          FRA         France      183.0
# ...

# %%
bios[bios['died_date'].isna()][:2]
# Out:
#    athlete_id               name   born_date born_city born_region  \
# 1           2     Arnaud Boetsch  1969-04-01    Meulan    Yvelines
# 5           6  Nicolas Chatelain  1970-01-13    Amiens       Somme
#
#   born_country     NOC  height_cm  weight_kg died_date
# 1          FRA  France      183.0       76.0       NaN
# 5          FRA  France      181.0       70.0       NaN

# %%
bios_new[["athlete_id","first_name","born_year"]]
# Out:
#         athlete_id     first_name  born_year
# 0                1  Jean-François     1886.0
# 1                2         Arnaud     1969.0
# 2                3           Jean     1898.0
# 3                4        Jacques     1895.0
# 4                5         Albert     1878.0
# ...            ...            ...        ...
# 145495      149222         Polina     2002.0
# 145496      149223       Valeriya     1999.0
# 145497      149224         Yuliya     1998.0
# 145498      149225          André     1899.0
# 145499      149814           Bill     1913.0
#
# [145500 rows x 3 columns]

# %%
bios_new.dropna(axis=0,inplace=True)

# %%
bios_new.head()
# Out:
#      athlete_id             name   born_date    born_city  \
# 2             3     Jean Borotra  1898-08-13     Biarritz
# 3             4  Jacques Brugnon  1895-05-11  Paris VIIIe
# 107         108   Anders Nielsen  1967-02-24    Cape Town
# 258         259   Tonny Maringgi  1959-06-10      Kendari
# 300         301     Jackson Fear  1978-01-13       Sydney
#
#               born_region born_country            NOC  height_cm  weight_kg  \
# 2    Pyrénées-Atlantiques          FRA         France      183.0       76.0
# 3                   Paris          FRA         France      168.0       64.0
# 107          Western Cape          RSA  Great Britain      173.0       70.0
# 258     Sulawesi Tenggara          INA      Indonesia      167.0       65.0
# 300       New South Wales          AUS      Australia      178.0      125.0
#
#       died_date first_name born_datetime  born_year
# 2    1994-07-17       Jean    1898-08-13     1898.0
# 3    1978-03-20    Jacques    1895-05-11     1895.0
# ...

# %%
bios_new.sort_values(ascending=True,by="born_year")
# Out:
#         athlete_id                       name   born_date        born_city  \
# 46960        47310                E. T. Jones  1850-05-07            Leeds
# 79312        79920    Charles Newton Robinson  1853-10-14       Kensington
# 79310        79918   William, Lord Desborough  1855-10-30      Westminster
# 79311        79919          Cosmo Duff-Gordon  1862-07-22           London
# 40387        40696                  Ed Hedley  1864-07-23     Philadelphia
# ...            ...                        ...         ...              ...
# 130984      133739                Abadi Hadis  1997-11-06      Addis Ababa
# 132713      135607           Abdalelah Haroun  1997-01-01          Al-Soki
# 128714      131271                Liv Podmore  1997-05-24     Christchurch
# 133701      136685  Ekaterina Alexandrovskaya  2000-01-01  Moskva (Moscow)
# 136653      139884            Johanna Bassani  2002-04-25      Vöcklabruck
#
# ...

# %%
bios_new.sort_values(ascending=False,by="height_cm")
# Out:
#        athlete_id                  name   born_date          born_city  \
# 5089         5108    Viktor Pankrashkin  1957-06-19    Moskva (Moscow)
# 6420         6451         Jānis Krūmiņš  1930-01-30              Cēsis
# 5683         5706  Aleksandr Belostenny  1959-02-24              Odesa
# 33129       33379         Peter Adelaar  1947-02-26          Amsterdam
# 89118       89830           Margo Dydek  1974-04-28  Warszawa (Warsaw)
# ...           ...                   ...         ...                ...
# 87215       87912           Ahmet Kıbıl  1952-12-15          Sarıkamış
# 50369       50727      Yelena Miroshina  1974-06-05    Moskva (Moscow)
# 40389       40698          Doug Herland  1951-08-19               Bend
# 56566       56969          Joe DePietro  1914-06-10           Paterson
# 58321       58736           Malwa Singh  1946-03-20              Delhi
#
#                                born_region born_country  \
# 5089                                Moskva          RUS
# ...

# %%
bios_new.merge(noc_regions,left_on="born_country",right_on="NOC",how="inner")
# Out:
#        athlete_id             name   born_date    born_city  \
# 0               3     Jean Borotra  1898-08-13     Biarritz
# 1               4  Jacques Brugnon  1895-05-11  Paris VIIIe
# 2             108   Anders Nielsen  1967-02-24    Cape Town
# 3             259   Tonny Maringgi  1959-06-10      Kendari
# 4             301     Jackson Fear  1978-01-13       Sydney
# ...           ...              ...         ...          ...
# 10725      138435        Art Child  1916-09-15     West Ham
# 10726      138440   Toyoko Yoshino  1920-02-12     Abashiri
# 10727      138446   Jacques Demaré  1900-09-01    Vincennes
# 10728      139884  Johanna Bassani  2002-04-25  Vöcklabruck
# 10729      144729    Naonobu Fujii  1992-01-05   Ishinomaki
#
#                 born_region born_country          NOC_x  height_cm  weight_kg  \
# 0      Pyrénées-Atlantiques          FRA         France      183.0       76.0
# 1                     Paris          FRA         France      168.0       64.0
# ...

# %%
bios_new.groupby(by="NOC")['NOC'].count()
# Out:
# NOC
# Afghanistan                 2
# Algeria                     3
# Angola                      2
# Argentina                 146
# Armenia                     2
#                          ...
# West Germany              157
# West Indies Federation      2
# Yugoslavia                237
# Zambia                     11
# Zimbabwe                   10
# Name: NOC, Length: 203, dtype: int64

# %%
bios_new.head()
# Out:
#      athlete_id             name   born_date    born_city  \
# 2             3     Jean Borotra  1898-08-13     Biarritz
# 3             4  Jacques Brugnon  1895-05-11  Paris VIIIe
# 107         108   Anders Nielsen  1967-02-24    Cape Town
# 258         259   Tonny Maringgi  1959-06-10      Kendari
# 300         301     Jackson Fear  1978-01-13       Sydney
#
#               born_region born_country            NOC  height_cm  weight_kg  \
# 2    Pyrénées-Atlantiques          FRA         France      183.0       76.0
# 3                   Paris          FRA         France      168.0       64.0
# 107          Western Cape          RSA  Great Britain      173.0       70.0
# 258     Sulawesi Tenggara          INA      Indonesia      167.0       65.0
# 300       New South Wales          AUS      Australia      178.0      125.0
#
#       died_date first_name born_datetime  born_year
# 2    1994-07-17       Jean    1898-08-13     1898.0
# 3    1978-03-20    Jacques    1895-05-11     1895.0
# ...

# %%
bios_new.dropna(inplace=True)
bios_new['born_datetime'] = pd.to_datetime(bios_new['born_datetime']) 
bios_new['died_date'] = pd.to_datetime(bios_new['died_date'])

# %%
bios_new.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 10753 entries, 2 to 141190
# Data columns (total 13 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   athlete_id     10753 non-null  int64
#  1   name           10753 non-null  object
#  2   born_date      10753 non-null  object
#  3   born_city      10753 non-null  object
#  4   born_region    10753 non-null  object
#  5   born_country   10753 non-null  object
#  6   NOC            10753 non-null  object
#  7   height_cm      10753 non-null  float64
#  8   weight_kg      10753 non-null  float64
#  9   died_date      10753 non-null  datetime64[ns]
#  10  first_name     10753 non-null  object
#  11  born_datetime  10753 non-null  datetime64[ns]
#  12  born_year      10753 non-null  float64
# dtypes: datetime64[ns](2), float64(3), int64(1), object(7)
# memory usage: 1.1+ MB

# %%
def calculate_age(x):
    x['age']= x['died_date'].year -x['born_datetime'].year
    return x
bios_new =bios_new.apply(calculate_age,axis=1)

# %%
bios_new.head()
# Out:
#      athlete_id             name   born_date    born_city  \
# 2             3     Jean Borotra  1898-08-13     Biarritz
# 3             4  Jacques Brugnon  1895-05-11  Paris VIIIe
# 107         108   Anders Nielsen  1967-02-24    Cape Town
# 258         259   Tonny Maringgi  1959-06-10      Kendari
# 300         301     Jackson Fear  1978-01-13       Sydney
#
#               born_region born_country            NOC  height_cm  weight_kg  \
# 2    Pyrénées-Atlantiques          FRA         France      183.0       76.0
# 3                   Paris          FRA         France      168.0       64.0
# 107          Western Cape          RSA  Great Britain      173.0       70.0
# 258     Sulawesi Tenggara          INA      Indonesia      167.0       65.0
# 300       New South Wales          AUS      Australia      178.0      125.0
#
#      died_date first_name born_datetime  born_year  age
# 2   1994-07-17       Jean    1898-08-13     1898.0   96
# ...

# %%
results.head()
# Out:
#      year    type discipline                     event                     as  \
# 0  1912.0  Summer     Tennis    Singles, Men (Olympic)  Jean-François Blanchy
# 1  1912.0  Summer     Tennis    Doubles, Men (Olympic)  Jean-François Blanchy
# 2  1920.0  Summer     Tennis    Singles, Men (Olympic)  Jean-François Blanchy
# 3  1920.0  Summer     Tennis  Doubles, Mixed (Olympic)  Jean-François Blanchy
# 4  1920.0  Summer     Tennis    Doubles, Men (Olympic)  Jean-François Blanchy
#
#    athlete_id  noc             team  place   tied medal
# 0           1  FRA              NaN   17.0   True   NaN
# 1           1  FRA   Jean Montariol    NaN  False   NaN
# 2           1  FRA              NaN   32.0   True   NaN
# 3           1  FRA  Jeanne Vaussard    8.0   True   NaN
# 4           1  FRA  Jacques Brugnon    4.0  False   NaN

# %%
results.groupby("athlete_id").size().reset_index(name="participations")
# Out:
#         athlete_id  participations
# 0                1               5
# 1                2               2
# 2                3               3
# 3                4               3
# 4                5               3
# ...            ...             ...
# 145257      148982               1
# 145258      148983               1
# 145259      148984               1
# 145260      148985               2
# 145261      148986               1
#
# [145262 rows x 2 columns]

# %%
 

results.groupby(by="noc")['medal'].apply(lambda x: x.notna().sum())
# Out:
# noc
# AFG      2
# AHO      1
# ALB      0
# ALG     17
# AND      1
#       ...
# YEM      0
# YMD      0
# YUG    390
# ZAM      2
# ZIM     22
# Name: medal, Length: 230, dtype: int64

# %% [markdown]
# ## 🔵 Advanced Tasks
#
# 1. **Join results with bios**
#
#    - Merge `results.csv` with `bios_new.csv` so each result row has athlete information (e.g., `born_country`, `height_cm`).
#
# 2. **Best country performance**
#
# - Group results by `noc` and count **gold/silver/bronze** separately.
# - Find which NOC has the highest total medals.
#
# 3. **Custom queries**
#
# - Find athletes who competed before they turned 25.
# - List all events where French athletes participated.
#
# 4. **Data cleaning**
#
# - Detect missing values (`NaN`) across all datasets.
# - Fill missing `height_cm` or `weight_kg` with the mean per `NOC`.

# %%
results.head()
# Out:
#      year    type discipline                     event                     as  \
# 0  1912.0  Summer     Tennis    Singles, Men (Olympic)  Jean-François Blanchy
# 1  1912.0  Summer     Tennis    Doubles, Men (Olympic)  Jean-François Blanchy
# 2  1920.0  Summer     Tennis    Singles, Men (Olympic)  Jean-François Blanchy
# 3  1920.0  Summer     Tennis  Doubles, Mixed (Olympic)  Jean-François Blanchy
# 4  1920.0  Summer     Tennis    Doubles, Men (Olympic)  Jean-François Blanchy
#
#    athlete_id  noc             team  place   tied medal
# 0           1  FRA              NaN   17.0   True   NaN
# 1           1  FRA   Jean Montariol    NaN  False   NaN
# 2           1  FRA              NaN   32.0   True   NaN
# 3           1  FRA  Jeanne Vaussard    8.0   True   NaN
# 4           1  FRA  Jacques Brugnon    4.0  False   NaN

# %%
bios_new.head()
# Out:
#      athlete_id             name   born_date    born_city  \
# 2             3     Jean Borotra  1898-08-13     Biarritz
# 3             4  Jacques Brugnon  1895-05-11  Paris VIIIe
# 107         108   Anders Nielsen  1967-02-24    Cape Town
# 258         259   Tonny Maringgi  1959-06-10      Kendari
# 300         301     Jackson Fear  1978-01-13       Sydney
#
#               born_region born_country            NOC  height_cm  weight_kg  \
# 2    Pyrénées-Atlantiques          FRA         France      183.0       76.0
# 3                   Paris          FRA         France      168.0       64.0
# 107          Western Cape          RSA  Great Britain      173.0       70.0
# 258     Sulawesi Tenggara          INA      Indonesia      167.0       65.0
# 300       New South Wales          AUS      Australia      178.0      125.0
#
#      died_date first_name born_datetime  born_year  age
# 2   1994-07-17       Jean    1898-08-13     1898.0   96
# ...

# %%
results.merge(bios_new,on="athlete_id",how="inner")
# Out:
#          year    type                discipline  \
# 0      1924.0  Summer                    Tennis
# 1      1924.0  Summer                    Tennis
# 2      1924.0  Summer                    Tennis
# 3      1920.0  Summer                    Tennis
# 4      1920.0  Summer                    Tennis
# ...       ...     ...                       ...
# 24941  1924.0  Summer                    Rowing
# 24942  2020.0  Winter  Nordic Combined (Skiing)
# 24943  2020.0  Winter  Nordic Combined (Skiing)
# 24944  2020.0  Winter  Nordic Combined (Skiing)
# 24945  2020.0  Summer   Volleyball (Volleyball)
#
#                                                    event               as  \
# 0                                 Singles, Men (Olympic)     Jean Borotra
# 1                               Doubles, Mixed (Olympic)     Jean Borotra
# 2                                 Doubles, Men (Olympic)     Jean Borotra
# 3                                 Singles, Men (Olympic)  Jacques Brugnon
# ...

# %%
results.dropna(subset="medal").groupby(['noc','medal']).size().unstack(fill_value=0) .reset_index()
# Out:
# medal  noc  Bronze  Gold  Silver
# 0      AFG       2     0       0
# 1      AHO       0     0       1
# 2      ALG       8     5       4
# 3      AND       1     0       0
# 4      ANZ       5    20       4
# ..     ...     ...   ...     ...
# 151    VIE       2     3       3
# 152    WIF       5     0       0
# 153    YUG      93   130     167
# 154    ZAM       1     0       1
# 155    ZIM       1    17       4
#
# [156 rows x 4 columns]

# %%
medal_count = (
    results.dropna(subset=["medal"])
           .groupby("noc")
           .size()
           .reset_index(name="medal_count")
           .sort_values("medal_count", ascending=False)
)
medal_count
# Out:
#      noc  medal_count
# 148  USA         5995
# 146  URS         2480
# 53   GER         2399
# 50   GBR         2199
# 47   FRA         2009
# ..   ...          ...
# 94   MON            1
# 117  SAM            1
# 137  TOG            1
# 125  SUD            1
# 133  TGA            1
#
# [156 rows x 2 columns]

# %%
bios_new[bios_new['age'] < 25]
# Out:
#         athlete_id                       name   born_date  \
# 1288          1295                Wang Runlan  1913-05-28
# 1339          1346           Robinson Pitalúa  1964-09-03
# 3081          3093           Vincent Sarnelli  1962-02-24
# 4449          4464              Charles Reiff  1940-12-27
# 4671          4688                 René Silva  1954-11-27
# ...            ...                        ...         ...
# 129453      132069               Kelly Catlin  1995-11-03
# 130984      133739                Abadi Hadis  1997-11-06
# 132713      135607           Abdalelah Haroun  1997-01-01
# 133701      136685  Ekaterina Alexandrovskaya  2000-01-01
# 136653      139884            Johanna Bassani  2002-04-25
#
#                      born_city     born_region born_country  \
# 1288                    Liuchu           Hebei          CHN
# 1339                  Montería         Córdoba          COL
# 3081    Villefranche-sur-Saône           Rhône          FRA
# ...

# %%
bios_new[bios_new['NOC']  == "France"]
# Out:
#         athlete_id             name   born_date            born_city  \
# 2                3     Jean Borotra  1898-08-13             Biarritz
# 3                4  Jacques Brugnon  1895-05-11          Paris VIIIe
# 2974          2986  Patrice Aouissi  1966-02-24                 Lyon
# 3003          3015   Aldo Cosentino  1947-10-19                Tunis
# 3022          3034     Paul Fritsch  1901-02-25            Paris XXe
# ...            ...              ...         ...                  ...
# 111683      112927    Jaoid Chiguer  1985-08-11               Troyes
# 113234      114525       Yves Niaré  1977-07-20  Bourg-Saint-Maurice
# 114910      116237    Laurent Vidal  1984-02-18                 Sète
# 116924      118348    David Poisson  1982-03-31               Annecy
# 135283      138446   Jacques Demaré  1900-09-01            Vincennes
#
#                  born_region born_country     NOC  height_cm  weight_kg  \
# ...

# %%
bios_new = pd.read_csv("./data/bios_new.csv")

# %%
bios_new.head(
)
# Out:
#    athlete_id                   name   born_date    born_city  \
# 0           1  Jean-François Blanchy  1886-12-12     Bordeaux
# 1           2         Arnaud Boetsch  1969-04-01       Meulan
# 2           3           Jean Borotra  1898-08-13     Biarritz
# 3           4        Jacques Brugnon  1895-05-11  Paris VIIIe
# 4           5           Albert Canet  1878-04-17   Wandsworth
#
#             born_region born_country     NOC  height_cm  weight_kg  \
# 0               Gironde          FRA  France        NaN        NaN
# 1              Yvelines          FRA  France      183.0       76.0
# 2  Pyrénées-Atlantiques          FRA  France      183.0       76.0
# 3                 Paris          FRA  France      168.0       64.0
# 4               England          GBR  France        NaN        NaN
#
#     died_date     first_name born_datetime  born_year
# 0  1960-10-02  Jean-François    1886-12-12     1886.0
# 1         NaN         Arnaud    1969-04-01     1969.0
# ...

# %%
bios_new.describe()
# Out:
#           athlete_id      height_cm      weight_kg      born_year
# count  145500.000000  106651.000000  102070.000000  143693.000000
# mean    73686.188955     176.333724      71.890996    1957.064464
# std     42868.960158      10.380282      14.465540      31.469023
# min         1.000000     127.000000      25.000000    1828.000000
# 25%     36663.750000     170.000000      62.000000    1939.000000
# 50%     73302.500000     176.000000      70.000000    1964.000000
# 75%    110306.250000     183.000000      80.000000    1982.000000
# max    149814.000000     226.000000     198.000000    2009.000000

# %%
bios_new.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 145500 entries, 0 to 145499
# Data columns (total 13 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   athlete_id     145500 non-null  int64
#  1   name           145500 non-null  object
#  2   born_date      143693 non-null  object
#  3   born_city      110908 non-null  object
#  4   born_region    110908 non-null  object
#  5   born_country   110908 non-null  object
#  6   NOC            145499 non-null  object
#  7   height_cm      106651 non-null  float64
#  8   weight_kg      102070 non-null  float64
#  9   died_date      33940 non-null   object
#  10  first_name     144586 non-null  object
#  11  born_datetime  143693 non-null  object
#  12  born_year      143693 non-null  float64
# dtypes: float64(3), int64(1), object(9)
# memory usage: 14.4+ MB

# %%
bios_new['height_cm'] = bios_new.groupby('NOC')['height_cm'].transform(
    lambda x: x.interpolate(method='linear').fillna(x.mean())
)
# Out:
#          index  Values
# 0            0     NaN
# 1            1   183.0
# 2            2   183.0
# 3            3   168.0
# 4            4   174.5
# ...        ...     ...
# 145495  145495   167.0
# 145496  145496   168.0
# 145497  145497   163.0
# 145498  145498   166.0
# 145499  145499   166.0
#
# [145500 rows x 2 columns]
